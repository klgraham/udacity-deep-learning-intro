# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)

# relative frequency of each word in corpus
freqs = {word: count/total_count for word, count in word_counts.items()}

# probability of word being discarded
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

# words that remain after subsampling will be used for training.
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import randint

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = randint(1,window_size)
    max = len(words)
    next_words = [words[i] for i in range(idx + 1, idx + r) if i > 0 and i < max]
    previous_words = [words[i] for i in range(idx - 1, idx - r) if i > 0 and i < max]
    
    context_words = previous_words
    context_words.extend(next_words)
    
    return context_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    embed = tf.nn.embedding_lookup (embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), name='softmax_w', stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab), name='softmax_b')
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6282 0.2616 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5915 0.2497 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4585 0.2947 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5485 0.3233 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4583 0.2976 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5267 0.2774 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5380 0.2659 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5022 0.2816 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4593 0.2302 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4277 0.2322 sec/batch
# Nearest to state: derails, indicate, husks, nightbreed, daft, oslo, berbers, iceberg,
# Nearest to people: honorary, amn, dissidents, austerities, trombonist, strafford, yeh, cottages,
# Nearest to some: baudot, quaestors, necromancy, lunations, hochdeutsch, guiscard, pawe, proverb,
# Nearest to time: canalized, packs, roxbury, metamorphoses, outpost, elfin, pennebaker, guildhall,
# Nearest to it: interludes, diels, csv, parapet, ganga, theosis, maureen, elblag,
# Nearest to if: ak, bast, throat, cayce, inflected, nerds, broadening, petrels,
# Nearest to most: zamora, pinsent, searchable, chalcolithic, walken, comparatively, archaeology, oscar,
# Nearest to there: blofeld, doctorates, widening, insert, beneath, makeover, commercial, cincinnati,
# Nearest to question: clickable, morgenstern, harmful, southeast, programmable, ircd, margherita, operettas,
# Nearest to pope: millet, servicemen, informed, eleazar, secrets, infections, cath, magni,
# Nearest to writers: evanston, disturb, haji, hass, pozsony, nightingale, intruder, abdicate,
# Nearest to freedom: mandriva, misogynistic, blinding, itv, cic, goh, csg, declarations,
# Nearest to report: puberty, speeded, derives, hibiscus, uterine, bottles, elongate, pundit,
# Nearest to bill: drawings, unsc, carnatic, objector, latent, jordi, tens, phosphorylation,
# Nearest to versions: lemnos, impairing, lett, meetings, parted, garrisons, ten, temples,
# Nearest to applications: palin, glows, willow, gaucho, tunku, reveals, speculations, openbsd,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5127 0.2367 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3853 0.2262 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4183 0.2446 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3228 0.2361 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.3075 0.2371 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.3202 0.2397 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.2592 0.2406 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1874 0.2478 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.2231 0.2490 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.1931 0.2447 sec/batch
# Nearest to state: indicate, nightbreed, husks, slowed, oslo, derails, warlike, perceptive,
# Nearest to people: dissidents, honorary, opened, trombonist, strafford, austerities, feedback, cottages,
# Nearest to some: baudot, necromancy, quisqueya, eastwood, guiscard, split, quaestors, speculative,
# Nearest to time: packs, christianity, roxbury, about, canalized, pennebaker, outpost, as,
# Nearest to it: interludes, he, represents, diels, theosis, flexible, distributor, gamba,
# Nearest to if: ak, concordat, petrels, longshanks, bast, karoline, throat, states,
# Nearest to most: zamora, comparatively, searchable, pinsent, count, wretch, walken, rodman,
# Nearest to there: commercial, doctorates, beneath, cincinnati, widening, blofeld, consonant, herat,
# Nearest to question: programmable, ircd, southeast, hairstyle, clickable, frente, harmful, kw,
# Nearest to pope: infections, millet, servicemen, secrets, lara, syzygy, informed, jorkens,
# Nearest to writers: evanston, haji, disturb, pozsony, hass, ecclesiastes, nightingale, mint,
# Nearest to freedom: mandriva, itv, interpreted, garnett, declarations, goh, blows, cic,
# Nearest to report: puberty, derives, speeded, hibiscus, uterine, working, elongate, bottles,
# Nearest to bill: drawings, unsc, objector, respond, optional, didn, abused, tens,
# Nearest to versions: meetings, ten, impairing, lett, seize, parted, lemnos, efforts,
# Nearest to applications: glows, willow, palin, tunku, gaucho, openbsd, speculations, broly,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.1604 0.2535 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.1116 0.2532 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 5.0889 0.2431 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 5.0326 0.2411 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9421 0.2584 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.9720 0.2615 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.9444 0.2519 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.9173 0.2861 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.9007 0.2355 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8917 0.2385 sec/batch
# Nearest to state: indicate, days, former, nightbreed, oslo, terminals, slowed, husks,
# Nearest to people: honorary, dissidents, opened, feedback, trombonist, domes, strafford, cottages,
# Nearest to some: split, speculative, safe, baudot, eastwood, airing, estonian, attack,
# Nearest to time: packs, nowadays, recalled, christianity, roxbury, canalized, about, outpost,
# Nearest to it: interludes, he, represents, solely, orthography, flexible, ganga, theosis,
# Nearest to if: concordat, ak, generic, karoline, throat, analogy, cannot, already,
# Nearest to most: zamora, comparatively, searchable, strengthening, condemned, oscar, wwii, negotiate,
# Nearest to there: commercial, beneath, insert, calls, agreement, doctorates, permit, widening,
# Nearest to question: programmable, southeast, hairstyle, ircd, kw, harmful, operated, near,
# Nearest to pope: infections, show, syzygy, secrets, miscommunication, informed, servicemen, millet,
# Nearest to writers: evanston, disturb, ecclesiastes, haji, pozsony, peak, mint, intruder,
# Nearest to freedom: itv, interpreted, responsible, blows, re, garnett, favoured, economic,
# Nearest to report: derives, puberty, tourism, speeded, working, issue, hibiscus, uterine,
# Nearest to bill: drawings, didn, unsc, tens, respond, ratified, duties, task,
# Nearest to versions: ten, meetings, came, seize, efforts, impairing, preparations, adverse,
# Nearest to applications: openbsd, glows, willow, speculations, reveals, palin, fertilizer, tunku,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8617 0.2452 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8121 0.2380 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.8107 0.2697 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7873 0.2417 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8427 0.2449 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7705 0.2373 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7666 0.2359 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7543 0.2301 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7503 0.2315 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7403 0.2293 sec/batch
# Nearest to state: thrown, indicate, oslo, terminals, rabbinic, former, occupation, perceptive,
# Nearest to people: honorary, dissidents, trombonist, opened, strafford, feedback, cottages, domes,
# Nearest to some: baudot, split, lunations, safe, estonian, speculative, airing, intension,
# Nearest to time: packs, nowadays, recalled, outpost, roxbury, canalized, metamorphoses, reformed,
# Nearest to it: interludes, he, phoenix, represents, diels, mining, ganga, orthography,
# Nearest to if: concordat, ak, throat, analogy, generic, karoline, cannot, conveys,
# Nearest to most: comparatively, zamora, strengthening, condemned, searchable, negotiate, pinsent, oscar,
# Nearest to there: commercial, insert, beneath, denominations, agreement, blofeld, decimal, widening,
# Nearest to question: programmable, harmful, ircd, hairstyle, southeast, operated, kw, legends,
# Nearest to pope: infections, informed, servicemen, secrets, show, syzygy, miscommunication, millet,
# Nearest to writers: evanston, ecclesiastes, disturb, mint, peak, haji, hewitt, abdicate,
# Nearest to freedom: itv, blows, responsible, declarations, re, favoured, garnett, economic,
# Nearest to report: puberty, derives, tourism, bottles, speeded, uterine, winnipeg, objective,
# Nearest to bill: drawings, duties, ratified, tens, respond, unsc, didn, task,
# Nearest to versions: ten, parted, temples, meetings, adverse, efforts, revolutions, seize,
# Nearest to applications: openbsd, willow, glows, speculations, palin, reveals, fertilizer, someone,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7203 0.2297 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7372 0.5001 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6857 0.7204 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6947 0.7011 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6917 0.6676 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6958 0.2717 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6494 0.1971 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5785 0.2706 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5112 0.2783 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5148 0.2688 sec/batch
# Nearest to state: thrown, samos, oslo, swans, nightbreed, litani, vile, oz,
# Nearest to people: honorary, dissidents, trombonist, opened, strafford, feedback, domes, cottages,
# Nearest to some: baudot, lunations, split, breed, intension, safe, speculative, instantiation,
# Nearest to time: packs, canalized, roxbury, recalled, nowadays, guildhall, supplant, metamorphoses,
# Nearest to it: interludes, represents, phoenix, werewolf, ganga, desirable, anarchic, diels,
# Nearest to if: ak, concordat, conveys, suffers, generic, bast, cannot, analogy,
# Nearest to most: searchable, zamora, strengthening, comparatively, archaeology, negotiate, condemned, oscar,
# Nearest to there: commercial, insert, denominations, widening, decimal, beneath, blofeld, subtracted,
# Nearest to question: harmful, programmable, hairstyle, ircd, kw, southeast, legends, operated,
# Nearest to pope: polish, informed, infections, secrets, servicemen, jorkens, dynasty, comneni,
# Nearest to writers: evanston, ecclesiastes, disturb, abdicate, nightingale, intruder, haji, peak,
# Nearest to freedom: itv, blows, economic, proconsular, pod, garnett, declarations, strengthen,
# Nearest to report: bottles, puberty, derives, winnipeg, tourism, working, relinquished, speeded,
# Nearest to bill: drawings, ratified, tens, duties, didn, respond, democratically, unsc,
# Nearest to versions: parted, saharan, ten, revolutions, temples, impairing, kekkonen, proclamations,
# Nearest to applications: openbsd, willow, glows, palin, speculations, catechumen, reveals, fertilizer,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4971 0.2857 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5032 0.2750 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4741 0.2730 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5147 0.2620 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4971 0.2490 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5214 0.2685 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.5020 0.2571 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4136 0.2453 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4341 0.2445 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4462 0.2770 sec/batch
# Nearest to state: samos, thrown, dint, berbers, louvain, litani, oslo, former,
# Nearest to people: honorary, trombonist, dissidents, domes, strafford, opened, revisionists, cottages,
# Nearest to some: baudot, quaestors, instantiation, lunations, breed, speculative, linguists, copyrighted,
# Nearest to time: packs, supplant, canalized, guildhall, constituted, recalled, roxbury, metamorphoses,
# Nearest to it: interludes, cohesion, represents, theosis, werewolf, diels, phoenix, solely,
# Nearest to if: cannot, we, bast, concordat, positive, suffers, generic, ak,
# Nearest to most: searchable, zamora, negotiate, flashing, comparatively, discussion, condemned, rodman,
# Nearest to there: insert, commercial, subtracted, denominations, widening, palette, decimal, blofeld,
# Nearest to question: programmable, harmful, ircd, hairstyle, legends, kw, insane, overkill,
# Nearest to pope: dynasty, comneni, servicemen, polish, jorkens, millet, infamous, infections,
# Nearest to writers: ecclesiastes, nightingale, abdicate, haji, evanston, hass, spa, syd,
# Nearest to freedom: itv, blows, proconsular, economic, declarations, garnett, pod, mandriva,
# Nearest to report: bottles, winnipeg, puberty, derives, relinquished, working, drafts, tourism,
# Nearest to bill: drawings, democratically, duties, didn, tens, ratified, jourdan, webster,
# Nearest to versions: parted, impairing, monoclonal, ten, kekkonen, saharan, adverse, meetings,
# Nearest to applications: openbsd, glows, willow, palin, catechumen, speculations, reveals, gaucho,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4325 0.2669 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4149 0.2684 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4431 0.2522 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4208 0.2712 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4250 0.2386 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4772 0.2365 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4049 0.2524 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3717 0.2329 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4285 0.2348 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3888 0.2482 sec/batch
# Nearest to state: louvain, samos, berbers, oslo, dint, litani, thrown, swans,
# Nearest to people: honorary, dissidents, domes, strafford, trombonist, revisionists, cottages, opened,
# Nearest to some: baudot, instantiation, lunations, copyrighted, breed, speculative, quaestors, split,
# Nearest to time: packs, supplant, recalled, slave, canalized, talvela, guildhall, metamorphoses,
# Nearest to it: interludes, cohesion, represents, organising, diels, theosis, solely, exceptional,
# Nearest to if: cannot, we, conveys, positive, concordat, bast, suffers, generic,
# Nearest to most: flashing, searchable, comparatively, negotiate, broken, strengthening, recycling, archaeology,
# Nearest to there: insert, commercial, subtracted, widening, palette, denominations, blofeld, decimal,
# Nearest to question: harmful, programmable, ircd, hairstyle, overkill, kw, man, frente,
# Nearest to pope: dynasty, comneni, servicemen, infamous, polish, xxiii, daughter, raul,
# Nearest to writers: nightingale, ecclesiastes, evanston, abdicate, hass, christa, syd, spa,
# Nearest to freedom: itv, economic, garnett, proconsular, responsible, blows, mandriva, usp,
# Nearest to report: bottles, puberty, petrarca, winnipeg, weathering, wav, drafts, sacrilege,
# Nearest to bill: drawings, democratically, duties, didn, ratified, webster, irian, jourdan,
# Nearest to versions: parted, queries, impairing, granular, kekkonen, ten, monoclonal, littlefield,
# Nearest to applications: openbsd, glows, willow, speculations, palin, computing, catechumen, fertilizer,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3822 0.2519 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4101 0.2444 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3978 0.2452 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3825 0.2661 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4100 0.2320 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4021 0.2281 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3978 0.2499 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3733 0.2461 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3623 0.2335 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3666 0.2301 sec/batch
# Nearest to state: louvain, judiciary, litani, oslo, constitutional, samos, former, berbers,
# Nearest to people: revisionists, domes, dissidents, honorary, strafford, verifies, trombonist, guatemala,
# Nearest to some: baudot, lunations, instantiation, copyrighted, wormhole, linguists, speculative, breed,
# Nearest to time: packs, supplant, recalled, canalized, slave, metamorphoses, riel, fokker,
# Nearest to it: interludes, cohesion, represents, supremely, exceptional, responsive, very, diels,
# Nearest to if: positive, we, cannot, conveys, bast, analogy, suffers, logarithm,
# Nearest to most: negotiate, searchable, flashing, zamora, strengthening, recycling, broken, condemned,
# Nearest to there: insert, palette, denominations, subtracted, distinction, widening, asserting, disagreement,
# Nearest to question: harmful, ircd, programmable, hairstyle, man, insane, flathead, overkill,
# Nearest to pope: dynasty, daughter, xxiii, servicemen, nazianzus, comneni, bund, polish,
# Nearest to writers: nightingale, ecclesiastes, evanston, hass, abdicate, christa, syd, haji,
# Nearest to freedom: economic, itv, garnett, anti, proconsular, strengthen, usp, blows,
# Nearest to report: bottles, tourism, petrarca, winnipeg, akayev, weathering, lulach, elongate,
# Nearest to bill: democratically, duties, drawings, webster, didn, ratified, jourdan, hillary,
# Nearest to versions: queries, parted, granular, monoclonal, littlefield, kekkonen, cheats, impairing,
# Nearest to applications: openbsd, glows, computing, willow, browser, windows, internet, speculations,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3378 0.2611 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2808 0.2367 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3872 0.2319 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3844 0.2265 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3734 0.2263 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3542 0.2271 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2927 0.2272 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3834 0.2330 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2395 0.2282 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2853 0.2285 sec/batch
# Nearest to state: former, swans, oslo, louvain, litani, judiciary, berbers, constitutional,
# Nearest to people: strafford, domes, revisionists, trombonist, dissidents, honorary, verifies, cottages,
# Nearest to some: baudot, lunations, quaestors, linguists, wormhole, instantiation, copyrighted, speculative,
# Nearest to time: packs, canalized, recalled, supplant, slave, elfin, metamorphoses, riel,
# Nearest to it: interludes, cohesion, very, represents, desirable, responsive, glow, tasted,
# Nearest to if: we, positive, cannot, logarithm, bast, analogy, iff, suffers,
# Nearest to most: negotiate, chalcolithic, sociobiology, comparatively, strengthening, zamora, recycling, searchable,
# Nearest to there: insert, denominations, subtracted, palette, disagreement, homeomorphic, asserting, thymus,
# Nearest to question: harmful, ircd, hairstyle, man, programmable, insane, mexica, flathead,
# Nearest to pope: dynasty, daughter, bund, nazianzus, servicemen, xxiii, duchess, comneni,
# Nearest to writers: nightingale, ecclesiastes, evanston, syd, hass, christa, scholarly, abdicate,
# Nearest to freedom: misogynistic, anti, economic, strengthen, garnett, oled, responsible, itv,
# Nearest to report: bottles, lulach, akayev, petrarca, working, wav, winnipeg, weathering,
# Nearest to bill: democratically, duties, drawings, didn, hillary, webster, ratified, jourdan,
# Nearest to versions: queries, littlefield, cheats, granular, os, parted, monoclonal, proprietary,
# Nearest to applications: openbsd, browser, glows, computing, windows, willow, internet, speculations,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3215 0.2328 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2941 0.2346 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3620 0.1143 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2473 0.2330 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1977 0.2282 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1857 0.2335 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1950 0.2270 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1656 0.2322 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2047 0.2266 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1683 0.2250 sec/batch
# Nearest to state: oslo, former, litani, judiciary, louvain, swans, constitutional, berbers,
# Nearest to people: revisionists, domes, strafford, trombonist, dissidents, honorary, cottages, suspiciously,
# Nearest to some: baudot, lunations, quaestors, wormhole, speculative, linguists, copyrighted, pdas,
# Nearest to time: canalized, packs, recalled, slave, elfin, supplant, guildhall, knuckle,
# Nearest to it: cohesion, interludes, represents, responsive, diels, very, lgm, glow,
# Nearest to if: cannot, suffers, we, bast, positive, analogy, logarithm, conveys,
# Nearest to most: chalcolithic, sociobiology, negotiate, strengthening, comparatively, archaeology, recycling, searchable,
# Nearest to there: denominations, subtracted, insert, disagreement, homeomorphic, palette, distinction, asserting,
# Nearest to question: harmful, ircd, hairstyle, man, mutually, graeco, programmable, insane,
# Nearest to pope: xxiii, dynasty, daughter, antipope, comneni, papal, nazianzus, bund,
# Nearest to writers: nightingale, ecclesiastes, syd, christa, evanston, disturb, hass, scholarly,
# Nearest to freedom: misogynistic, anti, strengthen, responsible, economic, garnett, usp, oled,
# Nearest to report: bottles, akayev, lulach, petrarca, working, weathering, winnipeg, universitaire,
# Nearest to bill: democratically, drawings, hillary, duties, jourdan, didn, carnatic, irian,
# Nearest to versions: os, queries, littlefield, cheats, proprietary, granular, graphical, parted,
# Nearest to applications: openbsd, browser, computing, windows, glows, internet, speculations, implementation,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2125 0.2321 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2136 0.2311 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1918 0.2387 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1012 0.2286 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1546 0.2291 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1387 0.2286 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1212 0.2287 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1398 0.2454 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1815 0.2443 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1298 0.2436 sec/batch
# Nearest to state: louvain, former, oslo, judiciary, litani, swans, university, tohoku,
# Nearest to people: dissidents, domes, revisionists, strafford, publicly, verifies, cottages, suspiciously,
# Nearest to some: baudot, lunations, quaestors, linguists, speculative, instantiation, wormhole, pdas,
# Nearest to time: canalized, packs, recalled, slave, supplant, elfin, hijra, bartos,
# Nearest to it: cohesion, very, responsive, interludes, represents, diels, glow, desirable,
# Nearest to if: cannot, we, suffers, conveys, bast, logarithm, positive, iff,
# Nearest to most: chalcolithic, comparatively, recycling, sociobiology, searchable, overlying, negotiate, delocalised,
# Nearest to there: denominations, subtracted, insert, homeomorphic, disagreement, waveforms, palette, distinction,
# Nearest to question: harmful, ircd, mutually, man, hairstyle, programmable, graeco, insane,
# Nearest to pope: antipope, xxiii, papal, dynasty, comneni, daughter, bund, rome,
# Nearest to writers: nightingale, ecclesiastes, christa, scholarly, evanston, syd, hass, disturb,
# Nearest to freedom: anti, misogynistic, economic, strengthen, garnett, oled, responsible, usp,
# Nearest to report: bottles, lulach, working, akayev, petrarca, weathering, antiparticles, objective,
# Nearest to bill: drawings, democratically, hillary, duties, carnatic, didn, jourdan, irian,
# Nearest to versions: os, queries, cheats, proprietary, littlefield, parted, graphical, update,
# Nearest to applications: openbsd, browser, glows, computing, speculations, windows, willow, internet,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1367 0.2346 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1901 0.2271 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1414 0.2293 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1087 0.2274 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1361 0.2215 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1375 0.2292 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1607 0.2249 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0880 0.2212 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1008 0.2228 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1332 0.2241 sec/batch
# Nearest to state: judiciary, louvain, oslo, swans, former, constitutional, university, tohoku,
# Nearest to people: guatemala, dissidents, strafford, verifies, domes, revisionists, publicly, cottages,
# Nearest to some: baudot, lunations, quaestors, speculative, linguists, wormhole, pdas, hydronium,
# Nearest to time: recalled, packs, canalized, slave, supplant, hijra, elfin, whorehouse,
# Nearest to it: cohesion, diels, lgm, brawling, responsive, very, interludes, desirable,
# Nearest to if: cannot, conveys, we, logarithm, suffers, bast, divinities, tuple,
# Nearest to most: chalcolithic, sociobiology, searchable, recycling, comparatively, flashing, negotiate, lasts,
# Nearest to there: denominations, disagreement, differentia, attested, subtracted, homeomorphic, distinction, insert,
# Nearest to question: harmful, ircd, mutually, graeco, man, tolerance, hairstyle, flathead,
# Nearest to pope: antipope, xxiii, papal, dynasty, bund, comneni, rome, nazianzus,
# Nearest to writers: nightingale, ecclesiastes, christa, evanston, syd, scholarly, hass, essayists,
# Nearest to freedom: anti, misogynistic, economic, strengthen, oled, responsible, garnett, clandestine,
# Nearest to report: bottles, lulach, akayev, petrarca, weathering, working, arista, objective,
# Nearest to bill: drawings, democratically, hillary, duties, didn, carnatic, irian, jourdan,
# Nearest to versions: os, queries, cheats, littlefield, update, parted, granular, jfs,
# Nearest to applications: openbsd, browser, glows, computing, speculations, internet, content, willow,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1586 0.2345 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1161 0.2265 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1424 0.2231 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1691 0.2257 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1180 0.2286 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0708 0.2212 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1373 0.2249 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0904 0.2256 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1560 0.2236 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1761 0.2222 sec/batch
# Nearest to state: oslo, louvain, judiciary, former, constitutional, swans, litani, constitution,
# Nearest to people: guatemala, dissidents, strafford, domes, revisionists, trombonist, states, cottages,
# Nearest to some: lunations, quaestors, baudot, wormhole, linguists, speculative, hochdeutsch, pdas,
# Nearest to time: recalled, canalized, elfin, slave, packs, asquith, whorehouse, nightly,
# Nearest to it: cohesion, very, brawling, diels, desirable, responsive, lgm, theosis,
# Nearest to if: cannot, we, conveys, bast, divinities, suffers, logarithm, ought,
# Nearest to most: chalcolithic, sociobiology, searchable, comparatively, flashing, tomcats, negotiate, bagdad,
# Nearest to there: denominations, disagreement, differentia, homeomorphic, distinction, attested, exalts, marquises,
# Nearest to question: harmful, graeco, mutually, ircd, insane, man, hairstyle, tolerance,
# Nearest to pope: antipope, xxiii, papal, nazianzus, bund, comneni, dynasty, rome,
# Nearest to writers: nightingale, ecclesiastes, christa, scholarly, syd, novelists, essayists, evanston,
# Nearest to freedom: anti, misogynistic, strengthen, economic, oled, clandestine, garnett, conspirators,
# Nearest to report: lulach, bottles, akayev, weathering, working, objective, petrarca, sofa,
# Nearest to bill: democratically, hillary, drawings, duties, didn, carnatic, jourdan, irian,
# Nearest to versions: os, queries, update, cheats, graphical, proprietary, littlefield, romance,
# Nearest to applications: openbsd, browser, glows, internet, speculations, zuse, computing, cohesive,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1906 0.2249 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1104 0.2229 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0961 0.2221 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1157 0.2207 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0068 0.2224 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0929 0.2257 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0953 0.2229 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0704 0.2223 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1561 0.0486 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0769 0.2227 sec/batch
# Nearest to state: oslo, louvain, former, litani, constitutional, judiciary, swans, status,
# Nearest to people: dissidents, guatemala, strafford, states, trombonist, domes, murray, kashubians,
# Nearest to some: quaestors, lunations, baudot, linguists, pdas, speculative, wormhole, instantiation,
# Nearest to time: canalized, bartos, slave, recalled, elfin, unwed, nightly, knuckle,
# Nearest to it: cohesion, very, needed, desirable, represents, lgm, cavallo, cementing,
# Nearest to if: cannot, we, logarithm, conveys, mathfrak, divinities, suffers, tuple,
# Nearest to most: sociobiology, chalcolithic, comparatively, recycling, archaeology, petrel, bagdad, searchable,
# Nearest to there: homeomorphic, differentia, denominations, disagreement, waveforms, decimal, palette, marquises,
# Nearest to question: harmful, mutually, graeco, insane, ircd, tolerance, case, mexica,
# Nearest to pope: antipope, papal, xxiii, nazianzus, bund, xv, comneni, rome,
# Nearest to writers: novelists, nightingale, essayists, scholarly, disturb, syd, christa, ecclesiastes,
# Nearest to freedom: misogynistic, strengthen, anti, economic, clandestine, malady, engaging, oled,
# Nearest to report: lulach, bottles, working, weathering, sofa, akayev, objective, universitaire,
# Nearest to bill: democratically, hillary, drawings, duties, carnatic, didn, nominated, dodger,
# Nearest to versions: os, update, queries, desktop, graphical, proprietary, ssl, ms,
# Nearest to applications: openbsd, browser, glows, speculations, internet, zuse, computing, workstation,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.9923 0.2290 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0267 0.2281 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0423 0.2241 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9933 0.2277 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0049 0.2255 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9849 0.2354 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0428 0.2251 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0413 0.2229 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0719 0.2256 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9284 0.2284 sec/batch
# Nearest to state: oslo, former, judiciary, louvain, constitutional, status, litani, university,
# Nearest to people: dissidents, guatemala, strafford, states, revisionists, prefer, taboos, murray,
# Nearest to some: quaestors, lunations, baudot, wormhole, pdas, speculative, linguists, hochdeutsch,
# Nearest to time: canalized, recalled, bartos, unwed, slave, nightly, knuckle, whorehouse,
# Nearest to it: cohesion, needed, lgm, desirable, very, cavallo, parapet, coluim,
# Nearest to if: cannot, we, logarithm, divinities, mathfrak, suffers, conveys, say,
# Nearest to most: chalcolithic, sociobiology, comparatively, recycling, tomcats, petrel, bagdad, lasts,
# Nearest to there: disagreement, denominations, differentia, homeomorphic, attested, commercial, exalts, marquises,
# Nearest to question: mutually, harmful, ircd, graeco, tolerance, insane, lunatic, appealed,
# Nearest to pope: antipope, xxiii, papal, nazianzus, xv, comneni, bund, rome,
# Nearest to writers: novelists, essayists, nightingale, scholarly, christa, disturb, ecclesiastes, mcgowan,
# Nearest to freedom: misogynistic, anti, economic, clandestine, strengthen, malady, pod, oled,
# Nearest to report: lulach, working, bottles, weathering, objective, sofa, universitaire, akayev,
# Nearest to bill: drawings, hillary, carnatic, democratically, duties, didn, nominated, dodger,
# Nearest to versions: os, update, queries, jfs, whist, olfaction, graphical, cheats,
# Nearest to applications: openbsd, browser, glows, speculations, zuse, internet, computing, workstation,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9629 0.2280 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9819 0.2215 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9456 0.2232 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.9857 0.2251 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0042 0.2243 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0090 0.2206 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.9927 0.2430 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0537 0.2373 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9657 0.2600 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9582 0.2410 sec/batch
# Nearest to state: former, oslo, university, louvain, judiciary, graduated, status, honorary,
# Nearest to people: dissidents, guatemala, states, anybody, taboos, strafford, revisionists, prefer,
# Nearest to some: quaestors, wormhole, lunations, baudot, pdas, speculative, linguists, instantiation,
# Nearest to time: canalized, recalled, unwed, bartos, demotic, whorehouse, handguard, elfin,
# Nearest to it: cohesion, brawling, lgm, cavallo, desirable, stricture, parapet, needed,
# Nearest to if: cannot, we, logarithm, iff, conveys, mathfrak, divinities, whenever,
# Nearest to most: sociobiology, comparatively, chalcolithic, recycling, searchable, flashing, bagdad, tomcats,
# Nearest to there: homeomorphic, differentia, disagreement, waveforms, denominations, blofeld, marquises, distinction,
# Nearest to question: harmful, mutually, graeco, ircd, tolerance, insane, flathead, case,
# Nearest to pope: antipope, papal, xxiii, nazianzus, comneni, bund, xv, chalcedon,
# Nearest to writers: novelists, essayists, disturb, nightingale, ecclesiastes, scholarly, christa, evanston,
# Nearest to freedom: economic, misogynistic, anti, clandestine, strengthen, oled, malady, engaging,
# Nearest to report: lulach, working, bottles, objective, actively, weathering, sofa, akayev,
# Nearest to bill: hillary, drawings, carnatic, duties, democratically, didn, nominated, dodger,
# Nearest to versions: os, update, queries, parted, jfs, whist, esr, romance,
# Nearest to applications: openbsd, browser, glows, speculations, zuse, internet, firefox, willow,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9912 0.2269 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.9913 0.2368 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0232 0.2390 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9725 0.2660 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0170 0.2467 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.9912 0.2399 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0033 0.2360 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.9985 0.2356 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0218 0.2242 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0254 0.2378 sec/batch
# Nearest to state: oslo, judiciary, louvain, former, constitutional, constitution, status, litani,
# Nearest to people: guatemala, dissidents, states, kashubians, americans, prefer, juvenal, strafford,
# Nearest to some: quaestors, lunations, wormhole, speculative, linguists, baudot, pdas, adjective,
# Nearest to time: canalized, recalled, whorehouse, bartos, demotic, supplant, hours, knuckle,
# Nearest to it: lgm, brawling, cohesion, cementing, very, stricture, parapet, tasted,
# Nearest to if: cannot, we, logarithm, mathfrak, conveys, divinities, whenever, iff,
# Nearest to most: chalcolithic, comparatively, sociobiology, bagdad, recycling, searchable, soto, cpsu,
# Nearest to there: differentia, exalts, denominations, disagreement, distinction, attested, blofeld, cardinal,
# Nearest to question: mutually, harmful, masons, graeco, tolerance, insane, ircd, gay,
# Nearest to pope: antipope, papal, xxiii, nazianzus, comneni, chalcedon, bund, rome,
# Nearest to writers: novelists, scholarly, essayists, disturb, mancunian, nightingale, christa, ecclesiastes,
# Nearest to freedom: economic, anti, misogynistic, clandestine, strengthen, oled, malady, engaging,
# Nearest to report: lulach, sofa, working, actively, weathering, petrarca, objective, akayev,
# Nearest to bill: hillary, democratically, duties, carnatic, nominated, drawings, didn, unsc,
# Nearest to versions: os, update, jfs, whist, esr, queries, cheats, pts,
# Nearest to applications: openbsd, browser, glows, speculations, zuse, internet, firefox, catechumen,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0149 0.3841 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9313 0.6715 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9612 0.6667 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.9972 0.4299 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0105 0.2931 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0505 0.2293 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0596 9.7348 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9943 0.2219 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9675 0.5701 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.9742 0.6971 sec/batch
# Nearest to state: louvain, oslo, former, judiciary, constitution, thatcher, university, honorary,
# Nearest to people: guatemala, dissidents, strafford, states, kashubians, americans, anybody, juvenal,
# Nearest to some: quaestors, wormhole, lunations, hochdeutsch, linguists, baudot, copyrighted, pdas,
# Nearest to time: recalled, whorehouse, canalized, asquith, martialed, bartos, knuckle, elfin,
# Nearest to it: very, brawling, cementing, cohesion, lgm, tasted, desirable, cavallo,
# Nearest to if: cannot, logarithm, we, mathfrak, iff, ought, rang, divinities,
# Nearest to most: chalcolithic, sociobiology, comparatively, soto, bagdad, recycling, searchable, persian,
# Nearest to there: differentia, homeomorphic, waveforms, disagreement, distinction, palette, exalts, blofeld,
# Nearest to question: mutually, graeco, masons, tolerance, insane, harmful, frente, abusers,
# Nearest to pope: antipope, papal, xxiii, nazianzus, comneni, xv, bund, chalcedon,
# Nearest to writers: novelists, essayists, scholarly, christa, ecclesiastes, disturb, mancunian, cookbook,
# Nearest to freedom: clandestine, misogynistic, economic, strengthen, anti, malady, oled, biconditional,
# Nearest to report: lulach, weathering, objective, sofa, working, petrarca, actively, investigations,
# Nearest to bill: hillary, duties, democratically, drawings, nominated, didn, carnatic, task,
# Nearest to versions: os, jfs, esr, update, whist, romance, cheats, kokomo,
# Nearest to applications: openbsd, glows, browser, zuse, speculations, firefox, cohesive, internet,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.8980 0.4166 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9507 0.2536 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9658 0.2505 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9831 0.2599 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
